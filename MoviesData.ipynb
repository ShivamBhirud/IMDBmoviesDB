# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
a = np.array(["Shivam",64,"Harish",58,"Aai",60,"Mama",68,"Papa",62])

# %%
plt.plot(a,"o")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-5f5ff97960d4> in <module>()
# ----> 1 plt.plot(a,"o")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
location1 = 'D:\DataScience Datasets\movie_metadata.csv'

# %%
import pandas as pd

# %%
movies = pd.read_table(location1,sep=',',header=None)

# %%
movies
# Out:
#                     0                   1                       2         3   \
# 0                color       director_name  num_critic_for_reviews  duration
# 1                Color       James Cameron                     723       178
# 2                Color      Gore Verbinski                     302       169
# 3                Color          Sam Mendes                     602       148
# 4                Color   Christopher Nolan                     813       164
# 5                  NaN         Doug Walker                     NaN       NaN
# 6                Color      Andrew Stanton                     462       132
# 7                Color           Sam Raimi                     392       156
# 8                Color        Nathan Greno                     324       100
# 9                Color         Joss Whedon                     635       141
# 10               Color         David Yates                     375       153
# ...

# %%
sLength = len(movies[3])
movies['1'] = np.random.randn(sLength)

# %%
movies
# Out:
#                      0                   1                       2         3  \
# 0                color       director_name  num_critic_for_reviews  duration
# 1                Color       James Cameron                     723       178
# 2                Color      Gore Verbinski                     302       169
# 3                Color          Sam Mendes                     602       148
# 4                Color   Christopher Nolan                     813       164
# 5                  NaN         Doug Walker                     NaN       NaN
# 6                Color      Andrew Stanton                     462       132
# 7                Color           Sam Raimi                     392       156
# 8                Color        Nathan Greno                     324       100
# 9                Color         Joss Whedon                     635       141
# 10               Color         David Yates                     375       153
# ...

# %%
movies.drop('1',axis=1)
# Out:
#                     0                   1                       2         3   \
# 0                color       director_name  num_critic_for_reviews  duration
# 1                Color       James Cameron                     723       178
# 2                Color      Gore Verbinski                     302       169
# 3                Color          Sam Mendes                     602       148
# 4                Color   Christopher Nolan                     813       164
# 5                  NaN         Doug Walker                     NaN       NaN
# 6                Color      Andrew Stanton                     462       132
# 7                Color           Sam Raimi                     392       156
# 8                Color        Nathan Greno                     324       100
# 9                Color         Joss Whedon                     635       141
# 10               Color         David Yates                     375       153
# ...

# %%
movies['29'] = np.random.randn(5044)

# %%
movies
# Out:
#                     0                   1                       2         3   \
# 0                color       director_name  num_critic_for_reviews  duration
# 1                Color       James Cameron                     723       178
# 2                Color      Gore Verbinski                     302       169
# 3                Color          Sam Mendes                     602       148
# 4                Color   Christopher Nolan                     813       164
# 5                  NaN         Doug Walker                     NaN       NaN
# 6                Color      Andrew Stanton                     462       132
# 7                Color           Sam Raimi                     392       156
# 8                Color        Nathan Greno                     324       100
# 9                Color         Joss Whedon                     635       141
# 10               Color         David Yates                     375       153
# ...

# %%
movies
# Out:
#                      0                   1                       2         3  \
# 0                color       director_name  num_critic_for_reviews  duration
# 1                Color       James Cameron                     723       178
# 2                Color      Gore Verbinski                     302       169
# 3                Color          Sam Mendes                     602       148
# 4                Color   Christopher Nolan                     813       164
# 5                  NaN         Doug Walker                     NaN       NaN
# 6                Color      Andrew Stanton                     462       132
# 7                Color           Sam Raimi                     392       156
# 8                Color        Nathan Greno                     324       100
# 9                Color         Joss Whedon                     635       141
# 10               Color         David Yates                     375       153
# ...

# %%
del movies['29']

# %%
a = movies[23]
a
# Out:
# 0       title_year
# 1             2009
# 2             2007
# 3             2015
# 4             2012
# 5              NaN
# 6             2012
# 7             2007
# 8             2010
# 9             2015
# 10            2009
# 11            2016
# 12            2006
# 13            2008
# 14            2006
# 15            2013
# 16            2013
# 17            2008
# 18            2012
# 19            2011
# 20            2012
# 21            2014
# 22            2012
# 23            2010
# 24            2013
# 25            2007
# 26            2005
# 27            1997
# 28            2016
# 29            2012
#            ...
# 5014          2002
# 5015          2009
# 5016          1991
# 5017          2015
# 5018          2013
# 5019          2003
# 5020          2015
# 5021          2011
# 5022          2005
# 5023          2014
# 5024          2009
# 5025          2011
# 5026          1972
# 5027          2004
# 5028          2000
# 5029          2007
# ...

# %%
final = ['']
for x in range(0,len(a)-1):
    b = float(a[x])
    if(1990<=b and 2016 >=b):
        final.append(a[x])

# %%
year_of_release = []
for x in final:
    year_of_release.append(int(x))

# %%
year_of_release
# Out:
# [2009,
#  2007,
#  2015,
#  2012,
#  2012,
#  2007,
#  2010,
#  2015,
#  2009,
#  2016,
#  2006,
#  2008,
#  2006,
#  2013,
#  2013,
#  2008,
#  2012,
#  2011,
#  2012,
#  2014,
#  2012,
#  2010,
#  2013,
#  2007,
#  2005,
#  1997,
#  2016,
#  2012,
#  2015,
#  2012,
#  2004,
#  2013,
#  2010,
#  2006,
#  2013,
#  2009,
#  2014,
#  2013,
#  2014,
#  2010,
#  2011,
#  2011,
#  2010,
#  2009,
#  2015,
#  2013,
#  2014,
#  2013,
#  2013,
#  2013,
#  2010,
#  2013,
#  2011,
#  2008,
#  2015,
#  2012,
#  2016,
#  2008,
#  2007,
#  2009,
#  2009,
#  2015,
#  2016,
#  2005,
#  2016,
#  2008,
#  2009,
#  2009,
#  2008,
#  2011,
#  1999,
#  2008,
#  2016,
#  2007,
#  2014,
#  1995,
#  2009,
#  2015,
#  2016,
#  2010,
#  2012,
#  2014,
#  2014,
#  2015,
#  2013,
#  2014,
#  2010,
#  2015,
#  2014,
#  2012,
#  2004,
#  2016,
#  2010,
#  2003,
#  2014,
#  2014,
#  2010,
#  2016,
#  2012,
#  2001,
#  2008,
#  2011,
#  2015,
#  2010,
#  2006,
#  2016,
#  2007,
#  2016,
#  2015,
#  2010,
#  2001,
# ...

# %%
del q
q=[]
for x in range(0,len(year_of_release)):
    q.append(x)
len(q)
# Out:
# 4382

# %%
plt.plot(year_of_release,q)
plt.xlabel('movies released')
plt.ylabel('count of movies')
plt.legend()
plt.show()
# Out:
# C:\Users\My\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# fixed bin size
bins = [1990,2000,2010,2020] # fixed bin size
#q = [1990,1990,2001,2004,2003,2001,2015,2015,2015,2015,2004,2004,1996,1996,1996]
#plt.xlim([min(year_of_release)-5, max(year_of_release)+5])

plt.hist(year_of_release, bins=bins,alpha = 0.5)
plt.xlabel("movies release date")
plt.ylabel("total count of movies released")
plt.legend()
plt.show()
# Out:
# C:\Users\My\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
type(year_of_release[0])
# Out:
# int

# %%
len(year_of_release)
# Out:
# 4382

# %%
cleaned
# Out:
# [0       2010
#  1       2009
#  2       2007
#  3       2015
#  4       2012
#  5        NaN
#  6       2012
#  7       2007
#  8       2010
#  9       2015
#  10      2009
#  11      2016
#  12      2006
#  13      2008
#  14      2006
#  15      2013
#  16      2013
#  17      2008
#  18      2012
#  19      2011
#  20      2012
#  21      2014
#  22      2012
#  23      2010
#  24      2013
#  25      2007
#  26      2005
#  27      1997
#  28      2016
#  29      2012
#          ...
#  5014    2002
#  5015    2009
#  5016    1991
#  5017    2015
#  5018    2013
#  5019    2003
#  5020    2015
#  5021    2011
#  5022    2005
#  5023    2014
#  5024    2009
#  5025    2011
#  5026    1972
#  5027    2004
#  5028    2000
#  5029    2007
#  5030    1997
#  5031    2004
#  5032    2012
#  5033    1995
#  5034    2004
#  5035    2005
#  5036    1992
#  5037    2005
#  5038    2011
#  5039    2013
#  5040     NaN
#  5041    2013
#  5042    2012
#  5043    2004
# ...

# %%
x = np.sort(movies[23])
y = np.arange(1,len(x)+1)/len(x)
_ = plt.plot(x,y,marker='.',linestyle='none')
_ = plt.xlabel("Year of release")
_ = plt.ylabel("movies released")
plt.margins(0.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-50b5f9d58765> in <module>()
# ----> 1 x = np.sort(movies[23])
#       2 y = np.arange(1,len(x)+1)/len(x)
#       3 _ = plt.plot(x,y,marker='.',linestyle='none')
#       4 _ = plt.xlabel("Year of release")
#       5 _ = plt.ylabel("movies released")
#
# C:\Users\My\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sort(a, axis, kind, order)
#     822     else:
#     823         a = asanyarray(a).copy(order="K")
# --> 824     a.sort(axis, kind, order)
#     825     return a
#     826
#
# TypeError: '>' not supported between instances of 'str' and 'float'
